# %%
# !unzip 3rhcxvngkl_\(2\)_7ul_i8dg2hf\ \(1\).zip
# Out:
# Archive:  3rhcxvngkl_(2)_7ul_i8dg2hf (1).zip
#   inflating: train(1).csv

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('train(1).csv')
df
# Out:
#              id  target  ...  ps_calc_19_bin  ps_calc_20_bin
# 0             7       0  ...               0               1
# 1             9       0  ...               1               0
# 2            13       0  ...               1               0
# 3            16       0  ...               0               0
# 4            17       0  ...               1               0
# ...         ...     ...  ...             ...             ...
# 595207  1488013       0  ...               1               1
# 595208  1488016       0  ...               1               1
# 595209  1488017       0  ...               0               0
# 595210  1488021       0  ...               0               0
# 595211  1488027       0  ...               0               0
#
# [595212 rows x 59 columns]

# %%
df[df==-1].count()
# Out:
# id                     0
# target                 0
# ps_ind_01              0
# ps_ind_02_cat        216
# ps_ind_03              0
# ps_ind_04_cat         83
# ps_ind_05_cat       5809
# ps_ind_06_bin          0
# ps_ind_07_bin          0
# ps_ind_08_bin          0
# ps_ind_09_bin          0
# ps_ind_10_bin          0
# ps_ind_11_bin          0
# ps_ind_12_bin          0
# ps_ind_13_bin          0
# ps_ind_14              0
# ps_ind_15              0
# ps_ind_16_bin          0
# ps_ind_17_bin          0
# ps_ind_18_bin          0
# ps_reg_01              0
# ps_reg_02              0
# ps_reg_03         107772
# ps_car_01_cat        107
# ps_car_02_cat          0
# ps_car_03_cat     411231
# ps_car_04_cat          0
# ps_car_05_cat     266551
# ps_car_06_cat          0
# ps_car_07_cat      11489
# ps_car_08_cat          0
# ps_car_09_cat        569
# ps_car_10_cat          0
# ps_car_11_cat          0
# ps_car_11              5
# ps_car_12              1
# ps_car_13              0
# ...

# %%
df1 = df.drop(['id','ps_ind_05_cat','ps_reg_03','ps_car_03_cat','ps_car_05_cat','ps_car_07_cat','ps_car_14'],axis=1)
df1
# Out:
#         target  ps_ind_01  ...  ps_calc_19_bin  ps_calc_20_bin
# 0            0          2  ...               0               1
# 1            0          1  ...               1               0
# 2            0          5  ...               1               0
# 3            0          0  ...               0               0
# 4            0          0  ...               1               0
# ...        ...        ...  ...             ...             ...
# 595207       0          3  ...               1               1
# 595208       0          5  ...               1               1
# 595209       0          1  ...               0               0
# 595210       0          5  ...               0               0
# 595211       0          0  ...               0               0
#
# [595212 rows x 52 columns]

# %%
df1['ps_ind_02_cat'].mean()
# Out:
# 1.3589426960477948

# %%
df1['ps_ind_02_cat'].replace({-1:1.358},inplace=True)

# %%
df1['ps_ind_04_cat'].mean()
# Out:
# 0.41679435226440326

# %%
df1['ps_ind_04_cat'].replace({-1:0.41679},inplace=True)

# %%
df1['ps_car_01_cat'].mean()
# Out:
# 8.29593321371209

# %%
df1['ps_car_01_cat'].replace({-1:8.295},inplace=True)

# %%
df1['ps_car_09_cat'].mean()
# Out:
# 1.3288895385173687

# %%
df1['ps_car_09_cat'].replace({-1:1.3288},inplace=True)

# %%
df1['ps_car_11'].mean()
# Out:
# 2.346071651781214

# %%
df1['ps_car_11'].replace({-1:2.346},inplace=True)

# %%
df1['ps_car_12'].mean()
# Out:
# 0.3799448151650683

# %%
df1['ps_car_12'].replace({-1:0.3799},inplace=True)

# %%
df1[df1==-1].count()
# Out:
# target            0
# ps_ind_01         0
# ps_ind_02_cat     0
# ps_ind_03         0
# ps_ind_04_cat     0
# ps_ind_06_bin     0
# ps_ind_07_bin     0
# ps_ind_08_bin     0
# ps_ind_09_bin     0
# ps_ind_10_bin     0
# ps_ind_11_bin     0
# ps_ind_12_bin     0
# ps_ind_13_bin     0
# ps_ind_14         0
# ps_ind_15         0
# ps_ind_16_bin     0
# ps_ind_17_bin     0
# ps_ind_18_bin     0
# ps_reg_01         0
# ps_reg_02         0
# ps_car_01_cat     0
# ps_car_02_cat     0
# ps_car_04_cat     0
# ps_car_06_cat     0
# ps_car_08_cat     0
# ps_car_09_cat     0
# ps_car_10_cat     0
# ps_car_11_cat     0
# ps_car_11         0
# ps_car_12         0
# ps_car_13         0
# ps_car_15         0
# ps_calc_01        0
# ps_calc_02        0
# ps_calc_03        0
# ps_calc_04        0
# ps_calc_05        0
# ps_calc_06        0
# ps_calc_07        0
# ps_calc_08        0
# ps_calc_09        0
# ps_calc_10        0
# ps_calc_11        0
# ps_calc_12        0
# ps_calc_13        0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

fig,ax = plt.subplots(figsize=(20,20))
correlation = df1.corr()
sns.heatmap(correlation,annot=True,ax = ax)

# %%
df1[df1==-1].count()
# Out:
# target            0
# ps_ind_01         0
# ps_ind_02_cat     0
# ps_ind_03         0
# ps_ind_04_cat     0
# ps_ind_06_bin     0
# ps_ind_07_bin     0
# ps_ind_08_bin     0
# ps_ind_09_bin     0
# ps_ind_10_bin     0
# ps_ind_11_bin     0
# ps_ind_12_bin     0
# ps_ind_13_bin     0
# ps_ind_14         0
# ps_ind_15         0
# ps_ind_16_bin     0
# ps_ind_17_bin     0
# ps_ind_18_bin     0
# ps_reg_01         0
# ps_reg_02         0
# ps_car_01_cat     0
# ps_car_02_cat     0
# ps_car_04_cat     0
# ps_car_06_cat     0
# ps_car_08_cat     0
# ps_car_09_cat     0
# ps_car_10_cat     0
# ps_car_11_cat     0
# ps_car_11         0
# ps_car_12         0
# ps_car_13         0
# ps_car_15         0
# ps_calc_01        0
# ps_calc_02        0
# ps_calc_03        0
# ps_calc_04        0
# ps_calc_05        0
# ps_calc_06        0
# ps_calc_07        0
# ps_calc_08        0
# ps_calc_09        0
# ps_calc_10        0
# ps_calc_11        0
# ps_calc_12        0
# ps_calc_13        0
# ...

# %%
from sklearn.model_selection import train_test_split
X = df1.drop(['target'],axis=1)
y = df1['target']
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=1)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (416648, 51)
# (178564, 51)
# (416648,)
# (178564,)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.barplot(x = 'ps_reg_01',y = 'target',data=df1)

# %%
sns.barplot(x = 'ps_car_06_cat',y = 'target',data=df1)

# %%
sns.barplot(x = 'ps_car_15',y = 'target',data=df1)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X_train,y_train)
y1_pred = lr.predict(X_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error

print(mean_squared_error(y_test,y1_pred))
# Out:
# 0.03623350731390426

# %%
from sklearn.metrics import accuracy_score
#accuracy = lr.score(X_test,y_test)
#print(accuracy)
print(accuracy_score(y_test,y1_pred))
# Out:
# 0.9637664926860957

# %%
from sklearn.metrics import confusion_matrix,classification_report
print(confusion_matrix(y_test,y1_pred))
print(classification_report(y_test,y1_pred))
# Out:
# [[172094      0]
#  [  6470      0]]
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98    172094
#            1       0.00      0.00      0.00      6470
#
#     accuracy                           0.96    178564
#    macro avg       0.48      0.50      0.49    178564
# weighted avg       0.93      0.96      0.95    178564
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn import metrics

rfc = RandomForestClassifier(n_estimators=30)
rfc.fit(X_train,y_train)
y_pred = rfc.predict(X_test)
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# 0.9637664926860957

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
rfc = RandomForestClassifier(n_estimators=30)
rfc.fit(X_train,y_train)
y_pred = rfc.predict(X_test)
abc = AdaBoostClassifier(base_estimator = rfc,learning_rate=1)
model = abc.fit(X_train,y_train)
y2_pred = model.predict(X_test)
print(metrics.accuracy_score(y_test,y2_pred))
print(metrics.f1_score(y_test,y_pred,average = 'weighted'))
# Out:
# 0.9637664926860957
# 0.9459840117283561

# %%
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
rfc = RandomForestClassifier(n_estimators=30)
rfc.fit(X_train,y_train)
y4_pred = rfc.predict(X_test)
abc = XGBClassifier(base_estimator = rfc,learning_rate=1)
model = abc.fit(X_train,y_train)
y5_pred = model.predict(X_test)
print(metrics.accuracy_score(y_test,y5_pred))
print(metrics.f1_score(y_test,y4_pred,average = 'weighted'))
# Out:
# 0.9635872852310656
# 0.9459840117283561

# %%
import sklearn
from sklearn import preprocessing
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report,confusion_matrix
le = preprocessing.LabelEncoder()
X = df1.drop(['target'],axis=1)
X = X.to_numpy()
y = df1['target']
y = y.to_numpy()
#y = y.apply(le.fit_transform)
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=1)
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

mlp = MLPClassifier(hidden_layer_sizes=(10,10,10),max_iter=1000)
mlp.fit(X_train,y_train)

predictions = mlp.predict(X_test)
print(confusion_matrix(y_test,predictions))
print(classification_report(y_test,predictions))
# Out:
# [[172094      0]
#  [  6470      0]]
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98    172094
#            1       0.00      0.00      0.00      6470
#
#     accuracy                           0.96    178564
#    macro avg       0.48      0.50      0.49    178564
# weighted avg       0.93      0.96      0.95    178564
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
mlp.score(X_test,y_test)
# Out:
# 0.9637664926860957

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
X,y = make_classification(n_samples=100,random_state=1)
X_train,X_test,y_train,y_test = train_test_split(X,y,stratify=y,random_state=1)
clf = MLPClassifier(random_state=1,max_iter = 300).fit(X_train,y_train)
print(clf.score(X_test,y_test))
# Out:
# 0.88
